# %%
import pandas as pd

# %%
#load files
file_path_1 = "C:\\Users\\LabUser\\Project_3\\School_Data\\ELSI_csv_export_1.csv"
file_path_2 = "C:\\Users\\LabUser\\Project_3\\School_Data\\ELSI_csv_export_2.csv"
file_path_3 = "C:\\Users\\LabUser\\Project_3\\School_Data\\ELSI_csv_export_3.csv"

# %%
#read files
data_1 = pd.read_csv(file_path_1, skiprows=6)
data_2 = pd.read_csv(file_path_2, skiprows=6)
data_3 = pd.read_csv(file_path_3, skiprows=6)

# %%
#drop ANSI/FIPS column
data_1 = data_1.drop(columns=['ANSI/FIPS State Code [Public School] Latest available year'])
data_2 = data_2.drop(columns=['ANSI/FIPS State Code [Public School] Latest available year'])
data_3 = data_3.drop(columns=['ANSI/FIPS State Code [Public School] Latest available year'])

# %%
#drop duplicates from each of the three files
data_1 = data_1.drop_duplicates()
data_2 = data_2.drop_duplicates()
data_3 = data_3.drop_duplicates()

# %%
data_1.drop_duplicates()
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 124865  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866  Data Source: U.S. Department of Education Nati...
# 124867      † indicates that the data are not applicable.
# 124868             – indicates that the data are missing.
# 124869  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...

# %%
data_2.drop_duplicates()
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 124865  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866  Data Source: U.S. Department of Education Nati...
# 124867      † indicates that the data are not applicable.
# 124868             – indicates that the data are missing.
# 124869  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...

# %%
#merge first and second data sets
merged_data_1_2 = pd.merge(data_1, data_2, on=['School Name', 'State Name [Public School] Latest available year'],
                how='left', suffixes=(None, '_overlapping'))

# %%
merged_data_1_2
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 164554  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 164555  Data Source: U.S. Department of Education Nati...
# 164556      † indicates that the data are not applicable.
# 164557             – indicates that the data are missing.
# 164558  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...

# %%
#remove overlapping columns
merged_data_1_2 = merged_data_1_2.loc[:, ~merged_data_1_2.columns.str.endswith('_overlapping')]

# %%
#drop columns with NaN
merged_data_1_2 = merged_data_1_2.dropna()

# %%
#merge 1&2 merged data with third data sets, remove overlapping columns
merged_data = pd.merge(merged_data_1_2, data_3,on=['School Name', 'State Name [Public School] Latest available year'],
            how='left', suffixes=(None, '_overlapping'))

# %%
#remove overlapping after final merge
merged_data = merged_data.loc[:, ~merged_data.columns.str.endswith('_overlapping')]

# %%
#remove rowns that have special characters in County Name row
merged_data = merged_data[~merged_data['County Name [Public School] 2013-14'].str.contains('†', na=False)]

# %%
#drop rows that have NaN in the final merged data set
merged_data = merged_data.dropna()

# %%
#drop duplicates based on school name
merged_data = merged_data.drop_duplicates(subset=['School Name'])

# %%
merged_data
# Out:
#                                          School Name  \
# 0                        `FRANKLIN ELEMENTARY SCHOOL
# 2                    1 LT CHARLES W. WHITCOMB SCHOOL
# 4       100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 5       100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 6            100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                              ...
# 580504                       ZUPANIC VIRTUAL ACADEMY
# 580505                                 ZURICH SCHOOL
# 580506                                      ZWINK EL
# 580507                      ZWOLLE ELEMENTARY SCHOOL
# 580508                            ZWOLLE HIGH SCHOOL
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 2                                         Massachusetts
# 4                                                Nevada
# 5                                                Nevada
# ...

# %%
# replace special characters with NA
data_cleaned = merged_data.replace({"†": pd.NA, "–": pd.NA, "‡": pd.NA})
data_cleaned
# Out:
#                                          School Name  \
# 0                        `FRANKLIN ELEMENTARY SCHOOL
# 2                    1 LT CHARLES W. WHITCOMB SCHOOL
# 4       100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 5       100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 6            100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                              ...
# 580504                       ZUPANIC VIRTUAL ACADEMY
# 580505                                 ZURICH SCHOOL
# 580506                                      ZWINK EL
# 580507                      ZWOLLE ELEMENTARY SCHOOL
# 580508                            ZWOLLE HIGH SCHOOL
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 2                                         Massachusetts
# 4                                                Nevada
# 5                                                Nevada
# ...

# %%
pd.set_option('display.max_columns', None)
print(data_cleaned.columns.tolist())
# Out:
# ['School Name', 'State Name [Public School] Latest available year', 'School ID - NCES Assigned [Public School] Latest available year', 'County Name [Public School] 2013-14', 'Location ZIP [Public School] 2013-14', 'Location City [Public School] 2013-14', 'School Type [Public School] 2013-14', 'Charter School [Public School] 2013-14', 'Charter School [Public School] 2012-13', 'Charter School [Public School] 2011-12', 'Charter School [Public School] 2010-11', 'Charter School [Public School] 2009-10', 'Charter School [Public School] 2008-09', 'Charter School [Public School] 2007-08', 'Charter School [Public School] 2006-07', 'Charter School [Public School] 2005-06', 'Charter School [Public School] 2004-05', 'Charter School [Public School] 2003-04', 'Charter School [Public School] 2002-03', 'Magnet School [Public School] 2013-14', 'Magnet School [Public School] 2012-13', 'Magnet School [Public School] 2011-12', 'Magnet School [Public School] 2010-11', 'Magnet School [Public School] 2009-
# ...

# %%
data_cleaned = data_cleaned.drop(columns=['Charter School [Public School] 2013-14', 
                                    'Charter School [Public School] 2012-13', 'Charter School [Public School] 2011-12', 
                                    'Charter School [Public School] 2010-11', 'Charter School [Public School] 2009-10', 
                                    'Charter School [Public School] 2008-09', 'Charter School [Public School] 2007-08', 
                                    'Charter School [Public School] 2006-07', 'Charter School [Public School] 2005-06', 
                                    'Charter School [Public School] 2004-05', 'Charter School [Public School] 2003-04', 
                                    'Charter School [Public School] 2002-03', 'Magnet School [Public School] 2013-14', 
                                    'Magnet School [Public School] 2012-13', 'Magnet School [Public School] 2011-12', 
                                    'Magnet School [Public School] 2010-11', 'Magnet School [Public School] 2009-10', 
                                    'Magnet School [Public School] 2008-09', 'Magnet School [Public School] 2007-08', 
                                    'Magnet School [Public School] 2006-07', 'Magnet School [Public School] 2005-06', 
                                    'Magnet School [Public School] 2004-05', 'Magnet School [Public School] 2003-04', 
                                    'Magnet School [Public School] 2002-03','Reduced-price Lunch Eligible Students [Public School] 2013-14', 
                                    'Reduced-price Lunch Eligible Students [Public School] 2012-13', 'Reduced-price Lunch Eligible Students [Public School] 2011-12', 
                                    'Reduced-price Lunch Eligible Students [Public School] 2010-11', 'Reduced-price Lunch Eligible Students [Public School] 2009-10', 
                                    'Reduced-price Lunch Eligible Students [Public School] 2008-09', 'Reduced-price Lunch Eligible Students [Public School] 2007-08', 
                                    'Reduced-price Lunch Eligible Students [Public School] 2006-07', 'Reduced-price Lunch Eligible Students [Public School] 2005-06', 
                                    'Reduced-price Lunch Eligible Students [Public School] 2004-05', 'Reduced-price Lunch Eligible Students [Public School] 2003-04', 
                                    'Reduced-price Lunch Eligible Students [Public School] 2002-03', 'Male Students [Public School] 2013-14',
                                    'Male Students [Public School] 2012-13', 'Male Students [Public School] 2011-12', 'Male Students [Public School] 2010-11', 
                                    'Male Students [Public School] 2009-10', 'Male Students [Public School] 2008-09', 'Male Students [Public School] 2007-08', 
                                    'Male Students [Public School] 2006-07', 'Male Students [Public School] 2005-06', 'Male Students [Public School] 2004-05', 
                                    'Male Students [Public School] 2003-04', 'Male Students [Public School] 2002-03', 'Female Students [Public School] 2013-14', 
                                    'Female Students [Public School] 2012-13', 'Female Students [Public School] 2011-12', 'Female Students [Public School] 2010-11',
                                    'Female Students [Public School] 2009-10', 'Female Students [Public School] 2008-09', 'Female Students [Public School] 2007-08',
                                    'Female Students [Public School] 2006-07', 'Female Students [Public School] 2005-06', 'Female Students [Public School] 2004-05',
                                    'Female Students [Public School] 2003-04', 'Female Students [Public School] 2002-03', 
                                    'American Indian/Alaska Native Students [Public School] 2013-14', 
                                    'American Indian/Alaska Native Students [Public School] 2012-13', 
                                    'American Indian/Alaska Native Students [Public School] 2011-12', 
                                    'American Indian/Alaska Native Students [Public School] 2010-11', 
                                    'American Indian/Alaska Native Students [Public School] 2009-10', 
                                    'American Indian/Alaska Native Students [Public School] 2008-09', 
                                    'American Indian/Alaska Native Students [Public School] 2007-08', 
                                    'American Indian/Alaska Native Students [Public School] 2006-07', 
                                    'American Indian/Alaska Native Students [Public School] 2005-06', 
                                    'American Indian/Alaska Native Students [Public School] 2004-05', 
                                    'American Indian/Alaska Native Students [Public School] 2003-04', 
                                    'American Indian/Alaska Native Students [Public School] 2002-03', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2013-14', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2012-13', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2011-12', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2010-11', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2009-10', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2008-09', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2007-08', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2006-07', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2005-06', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2004-05', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2003-04', 
                                    'Asian or Asian/Pacific Islander Students [Public School] 2002-03', 
                                    'Hispanic Students [Public School] 2013-14', 'Hispanic Students [Public School] 2012-13', 
                                    'Hispanic Students [Public School] 2011-12', 'Hispanic Students [Public School] 2010-11', 
                                    'Hispanic Students [Public School] 2009-10', 'Hispanic Students [Public School] 2008-09', 
                                    'Hispanic Students [Public School] 2007-08', 'Hispanic Students [Public School] 2006-07', 
                                    'Hispanic Students [Public School] 2005-06', 'Hispanic Students [Public School] 2004-05', 
                                    'Hispanic Students [Public School] 2003-04', 'Hispanic Students [Public School] 2002-03', 
                                    'Black or African American Students [Public School] 2013-14', 'Black or African American Students [Public School] 2012-13', 
                                    'Black or African American Students [Public School] 2011-12', 'Black or African American Students [Public School] 2010-11', 
                                    'Black or African American Students [Public School] 2009-10', 'Black or African American Students [Public School] 2008-09', 
                                    'Black or African American Students [Public School] 2007-08', 'Black or African American Students [Public School] 2006-07', 
                                    'Black or African American Students [Public School] 2005-06', 'Black or African American Students [Public School] 2004-05', 
                                    'Black or African American Students [Public School] 2003-04', 'Black or African American Students [Public School] 2002-03', 
                                    'White Students [Public School] 2013-14', 'White Students [Public School] 2012-13', 'White Students [Public School] 2011-12', 
                                    'White Students [Public School] 2010-11', 'White Students [Public School] 2009-10', 'White Students [Public School] 2008-09', 
                                    'White Students [Public School] 2007-08', 'White Students [Public School] 2006-07', 'White Students [Public School] 2005-06', 
                                    'White Students [Public School] 2004-05', 'White Students [Public School] 2003-04', 'White Students [Public School] 2002-03', 
                                    'Full-Time Equivalent (FTE) Teachers [Public School] 2013-14', 'Full-Time Equivalent (FTE) Teachers [Public School] 2012-13', 
                                    'Full-Time Equivalent (FTE) Teachers [Public School] 2011-12', 'Full-Time Equivalent (FTE) Teachers [Public School] 2010-11', 
                                    'Full-Time Equivalent (FTE) Teachers [Public School] 2009-10', 'Full-Time Equivalent (FTE) Teachers [Public School] 2008-09', 
                                    'Full-Time Equivalent (FTE) Teachers [Public School] 2007-08', 'Full-Time Equivalent (FTE) Teachers [Public School] 2006-07', 
                                    'Full-Time Equivalent (FTE) Teachers [Public School] 2005-06', 'Full-Time Equivalent (FTE) Teachers [Public School] 2004-05', 
                                    'Full-Time Equivalent (FTE) Teachers [Public School] 2003-04', 'Full-Time Equivalent (FTE) Teachers [Public School] 2002-03',])

# %%
data_cleaned
# Out:
#                                          School Name  \
# 0                        `FRANKLIN ELEMENTARY SCHOOL
# 2                    1 LT CHARLES W. WHITCOMB SCHOOL
# 4       100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 5       100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 6            100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                              ...
# 580504                       ZUPANIC VIRTUAL ACADEMY
# 580505                                 ZURICH SCHOOL
# 580506                                      ZWINK EL
# 580507                      ZWOLLE ELEMENTARY SCHOOL
# 580508                            ZWOLLE HIGH SCHOOL
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 2                                         Massachusetts
# 4                                                Nevada
# 5                                                Nevada
# ...

# %%
data_cleaned.index.names=["Schools_Index"]

# %%
#print to CSV
data_cleaned.to_csv('Schools_Merged_Data_2.csv')
