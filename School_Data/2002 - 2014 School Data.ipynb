# %%
import pandas as pd

# %%
#code_sheet = pd.read_csv("C:\\Users\\LabUser\\Project_3\\School_Data\\Resources\\all-geocodes-v2020.csv")

# %%
#code_sheet.head()

# %%
#code_sheet.dtypes

# %%
#code_sheet['Place Code (FIPS)'].unique()

# %%
#code_sheet.head()

# %%
#code_states = code_sheet[code_sheet['Summary Level'] == 40]
#code_states.head()

# %%
#code_states.tail()

# %%
#load and read files
file_path_1 = file_path = "C:\\Users\\LabUser\\Project_3\\School_Data\\ELSI_csv_export_1.csv"

# Skip to actual data
data_1 = pd.read_csv(file_path_1, skiprows=6)
data_1
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 124865  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866  Data Source: U.S. Department of Education Nati...
# 124867      † indicates that the data are not applicable.
# 124868             – indicates that the data are missing.
# 124869  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...

# %%
data_1.shape
# Out:
# (124870, 68)

# %%
data_1['School Name'].unique
# Out:
# <bound method Series.unique of 0                               `FRANKLIN ELEMENTARY SCHOOL
# 1                                                     03-MM
# 2                           1 LT CHARLES W. WHITCOMB SCHOOL
# 3         1 SCHOOL                                      ...
# 4              100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
#                                 ...
# 124865    ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866    Data Source: U.S. Department of Education Nati...
# 124867        † indicates that the data are not applicable.
# 124868               – indicates that the data are missing.
# 124869    ‡ indicates that the data do not meet NCES dat...
# Name: School Name, Length: 124870, dtype: object>

# %%
#load and read file
file_path_2 = file_path = "C:\\Users\\LabUser\\Project_3\\School_Data\\ELSI_csv_export_2.csv"

# Skip to actual data
data_2 = pd.read_csv(file_path_2, skiprows=6)
data_2
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 124865  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866  Data Source: U.S. Department of Education Nati...
# 124867      † indicates that the data are not applicable.
# 124868             – indicates that the data are missing.
# 124869  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...

# %%
data_2.shape
# Out:
# (124870, 75)

# %%
data_2['School Name'].unique
# Out:
# <bound method Series.unique of 0                               `FRANKLIN ELEMENTARY SCHOOL
# 1                                                     03-MM
# 2                           1 LT CHARLES W. WHITCOMB SCHOOL
# 3         1 SCHOOL                                      ...
# 4              100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
#                                 ...
# 124865    ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866    Data Source: U.S. Department of Education Nati...
# 124867        † indicates that the data are not applicable.
# 124868               – indicates that the data are missing.
# 124869    ‡ indicates that the data do not meet NCES dat...
# Name: School Name, Length: 124870, dtype: object>

# %%
#load and read files
file_path_3 = file_path = "C:\\Users\\LabUser\\Project_3\\School_Data\\ELSI_csv_export_3.csv"

# Skip to actual data
data_3 = pd.read_csv(file_path_3, skiprows=6)
data_3.head()
# Out:
#                                          School Name  \
# 0                        `FRANKLIN ELEMENTARY SCHOOL
# 1                                              03-MM
# 2                    1 LT CHARLES W. WHITCOMB SCHOOL
# 3  1 SCHOOL                                      ...
# 4       100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
#
#   State Name [Public School] Latest available year  \
# 0                                       New Jersey
# 1                                          Florida
# 2                                    Massachusetts
# 3                                         New York
# 4                                           Nevada
#
#    ANSI/FIPS State Code [Public School] Latest available year  \
# 0                                               34.0
# 1                                               12.0
# 2                                               25.0
# 3                                               36.0
# 4                                               32.0
# ...

# %%
data_3.shape
# Out:
# (124870, 39)

# %%
#merged_data = pd.concat([data_1, data_2, data_3], ignore_index=True)
#merged_data.head()

# %%
merged_data_1_2 = pd.merge(data_1, data_2, on=['School Name', 'State Name [Public School] Latest available year'], how='left', suffixes=(None, '_overlapping'))
merged_data_1_2 = merged_data_1_2.loc[:, ~merged_data_1_2.columns.str.endswith('_overlapping')]
merged_data_1_2.tail()
# Out:
#                                               School Name  \
# 196485  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 196486  Data Source: U.S. Department of Education Nati...
# 196487      † indicates that the data are not applicable.
# 196488             – indicates that the data are missing.
# 196489  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 196485                                        Louisiana
# 196486                                              NaN
# 196487                                              NaN
# 196488                                              NaN
# 196489                                              NaN
#
#         School ID - NCES Assigned [Public School] Latest available year  \
# 196485                                       2.201380e+11
# 196486                                                NaN
# 196487                                                NaN
# ...

# %%
merged_data_1_2 = merged_data_1_2.loc[merged_data_1_2['County Name [Public School] 2013-14'] != "†"]
merged_data_1_2
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 5            100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 6                 100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                                   ...
# 196484                                 ZWOLLE HIGH SCHOOL
# 196486  Data Source: U.S. Department of Education Nati...
# 196487      † indicates that the data are not applicable.
# 196488             – indicates that the data are missing.
# 196489  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 2                                         Massachusetts
# 4                                                Nevada
# ...

# %%
#merged_data_1_2.tail()
merged_data_1_2.dropna()
# Out:
#                                          School Name  \
# 0                        `FRANKLIN ELEMENTARY SCHOOL
# 2                    1 LT CHARLES W. WHITCOMB SCHOOL
# 4       100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 5       100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 6            100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                              ...
# 196480                       ZUPANIC VIRTUAL ACADEMY
# 196481                                 ZURICH SCHOOL
# 196482                                      ZWINK EL
# 196483                      ZWOLLE ELEMENTARY SCHOOL
# 196484                            ZWOLLE HIGH SCHOOL
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 2                                         Massachusetts
# 4                                                Nevada
# 5                                                Nevada
# ...

# %%
merged_data_1_2.drop_duplicates()
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 5            100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 6                 100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                                   ...
# 196484                                 ZWOLLE HIGH SCHOOL
# 196486  Data Source: U.S. Department of Education Nati...
# 196487      † indicates that the data are not applicable.
# 196488             – indicates that the data are missing.
# 196489  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 2                                         Massachusetts
# 4                                                Nevada
# ...

# %%
merged_data_1_2['School Name'].unique
# Out:
# <bound method Series.unique of 0                               `FRANKLIN ELEMENTARY SCHOOL
# 2                           1 LT CHARLES W. WHITCOMB SCHOOL
# 4              100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 5              100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 6                   100 BLACK MEN OF THE BAY AREA COMMUNITY
#                                 ...
# 196484                                   ZWOLLE HIGH SCHOOL
# 196486    Data Source: U.S. Department of Education Nati...
# 196487        † indicates that the data are not applicable.
# 196488               – indicates that the data are missing.
# 196489    ‡ indicates that the data do not meet NCES dat...
# Name: School Name, Length: 134212, dtype: object>

# %%
merged_data = pd.merge(merged_data_1_2, data_3, on='School Name', how='left', suffixes=(None, '_overlapping'))
merged_data= merged_data.loc[:, ~merged_data.columns.str.endswith('_overlapping')]
merged_data
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                         1 LT CHARLES W. WHITCOMB SCHOOL
# 2            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 3            100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 4                 100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                                   ...
# 992567                                 ZWOLLE HIGH SCHOOL
# 992568  Data Source: U.S. Department of Education Nati...
# 992569      † indicates that the data are not applicable.
# 992570             – indicates that the data are missing.
# 992571  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                         Massachusetts
# 2                                                Nevada
# ...

# %%
merged_data = merged_data.loc[merged_data['County Name [Public School] 2013-14'] != "†"]
merged_data
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                         1 LT CHARLES W. WHITCOMB SCHOOL
# 2            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 3            100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 4                 100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                                   ...
# 992567                                 ZWOLLE HIGH SCHOOL
# 992568  Data Source: U.S. Department of Education Nati...
# 992569      † indicates that the data are not applicable.
# 992570             – indicates that the data are missing.
# 992571  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                         Massachusetts
# 2                                                Nevada
# ...

# %%
merged_data.dropna()
# Out:
#                                          School Name  \
# 0                        `FRANKLIN ELEMENTARY SCHOOL
# 1                    1 LT CHARLES W. WHITCOMB SCHOOL
# 2       100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 3       100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 4            100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                              ...
# 992563                       ZUPANIC VIRTUAL ACADEMY
# 992564                                 ZURICH SCHOOL
# 992565                                      ZWINK EL
# 992566                      ZWOLLE ELEMENTARY SCHOOL
# 992567                            ZWOLLE HIGH SCHOOL
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                         Massachusetts
# 2                                                Nevada
# 3                                                Nevada
# ...

# %%
merged_data.drop_duplicates(['School Name'])
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                         1 LT CHARLES W. WHITCOMB SCHOOL
# 2            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 3            100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 4                 100 BLACK MEN OF THE BAY AREA COMMUNITY
# ...                                                   ...
# 992567                                 ZWOLLE HIGH SCHOOL
# 992568  Data Source: U.S. Department of Education Nati...
# 992569      † indicates that the data are not applicable.
# 992570             – indicates that the data are missing.
# 992571  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                         Massachusetts
# 2                                                Nevada
# ...

# %%
merged_data.to_csv('Schools Merged Data.csv')

# %%
merged_data.shape
# Out:
# (992572, 176)

# %%
#merged_data.columns

# %%
# replace special characters
#data_cleaned = data.replace({"†": pd.NA, "–": pd.NA, "‡": pd.NA})
#data_cleaned.head()

# %%
#data_cleaned = data_cleaned.apply(pd.to_numeric, errors='ignore')
#data_cleaned.head()

# %%
# drop rows with missing values
#data_cleaned = data_cleaned.dropna()
#data_cleaned

# %%
data_1
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 124865  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866  Data Source: U.S. Department of Education Nati...
# 124867      † indicates that the data are not applicable.
# 124868             – indicates that the data are missing.
# 124869  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...

# %%
data_2
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 124865  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866  Data Source: U.S. Department of Education Nati...
# 124867      † indicates that the data are not applicable.
# 124868             – indicates that the data are missing.
# 124869  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...

# %%
data_3
# Out:
#                                               School Name  \
# 0                             `FRANKLIN ELEMENTARY SCHOOL
# 1                                                   03-MM
# 2                         1 LT CHARLES W. WHITCOMB SCHOOL
# 3       1 SCHOOL                                      ...
# 4            100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# ...                                                   ...
# 124865  ZWOLLE INTERMEDIATE SCHOOL                    ...
# 124866  Data Source: U.S. Department of Education Nati...
# 124867      † indicates that the data are not applicable.
# 124868             – indicates that the data are missing.
# 124869  ‡ indicates that the data do not meet NCES dat...
#
#        State Name [Public School] Latest available year  \
# 0                                            New Jersey
# 1                                               Florida
# 2                                         Massachusetts
# ...
